# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[10])

for i in range(len(y)):
    x.append(i)

params = {'text.usetex': True}

plt.plot(x,y)
plt.xlabel('Grid Position')
plt.ylabel('Electric Potential')
plt.title('Finite-Difference Solution of Laplace Equation')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('exact_data.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[10])

for i in range(len(y)):
    x.append(i)

params = {'text.usetex': True}

plt.plot(x,y)
plt.xlabel('Grid Position')
plt.ylabel('Electric Potential')
plt.title('Exact Solution of Laplace Equation')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('exact_data.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[0])

for i in range(len(y)):
    x.append(i)

params = {'text.usetex': True}

plt.plot(x,y)
plt.xlabel('Grid Position')
plt.ylabel('Electric Potential')
plt.title('Exact Solution of Laplace Equation')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv

H = np.array([[1, 1, 1, 1],
              [1, 3, 2, 2],
              [1, 2, 3, 3],
              [1, 2, 3, 4]])  # added some commas and array creation code

fig = plt.figure(figsize=(6, 3.2))

ax = fig.add_subplot(111)
ax.set_title('colorMap')
plt.imshow(H)
ax.set_aspect('equal')

cax = fig.add_axes([0.12, 0.1, 0.78, 0.8])
cax.get_xaxis().set_visible(False)
cax.get_yaxis().set_visible(False)
cax.patch.set_alpha(0)
cax.set_frame_on(False)
plt.colorbar(orientation='vertical')
plt.show()
