# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []
z = []

with open('data226.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x.append(int(row[0]))
        y.append(int(row[2]))

with open('data245.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        z.append(int(row[2]))        
        
plt.plot(x,y, label='KbT/J = 2.26')
plt.plot(x,z, label='KbT/J = 2.45')
plt.xlabel('Monte Carlo Time')
plt.ylabel('Magnetization')
plt.title('Magnetization vs. Monte Carlo Time')
plt.legend(loc='center right')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data20.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x.append(int(row[0]))
        y.append(int(row[2]))

plt.plot(x,y);
plt.xlabel('Monte Carlo Time')
plt.ylabel('Magnetization')
plt.title('Magnetization vs. Monte Carlo Time')
plt.show()

# %%
#!/usr/bin/env python
import numpy as np
import matplotlib.pyplot as plt

# example data
x = [2.0, 2.05, 2.1, 2.15, 2.2, 2.25, 2.3, 2.35, 2.4, 2.45, 2.50]
y = [-147.864, -199.632, -142.668, -159.94, -169.868, -190.004, -138.672, -172.732, -178.052, -159.424, -151.824]

# First illustrate basic pyplot interface, using defaults where possible.
plt.scatter(x,y)
plt.errorbar(x, y, yerr=[4.7914, 2.37162, 8.04399, 0.48621, 3.54381, 3.32746, 2.23348, 4.2774, 5.61688, 9.05208, 2.97742], fmt = "none")
plt.title("Average Energy vs. Temperature")
plt.xlabel('KbT/J')
plt.ylabel('Energy')

plt.show()

# %%
#!/usr/bin/env python
import numpy as np
import matplotlib.pyplot as plt

# example data
x = [2.0, 2.05, 2.1, 2.15, 2.2, 2.25, 2.3, 2.35, 2.4, 2.45, 2.50]
y = [18.9444, 48.6814, 17.8893, 25.5006, 37.3617, 42.1882, 3.16991, 33.0461, 35.6481, 22.8933, 9.08885]

# First illustrate basic pyplot interface, using defaults where possible.
plt.scatter(x,y)
plt.errorbar(x, y, yerr=[7.50994, 0.68497, 13.416, 2.06488, 2.24723, 0.948801, 6.02807, 4.89325, 1.49858, 7.9227, 10.1342], fmt = "none")
plt.title("X vs. Temperature")
plt.xlabel('KbT/J')
plt.ylabel('X')

plt.show()

# %%
#!/usr/bin/env python
import numpy as np
import matplotlib.pyplot as plt

# example data
x = [2.0, 2.05, 2.1, 2.15, 2.2, 2.25, 2.3, 2.35, 2.4, 2.45, 2.50]
y = [0.114788, 0.027437, 0.308123, 0.00109953, 0.0570844, 0.0492088, 0.0216888, 0.0778561, 0.131455, 0.33445, 0.0354601]

# First illustrate basic pyplot interface, using defaults where possible.
plt.scatter(x,y)
plt.errorbar(x, y, yerr=[4.7914, 2.37162, 8.04399, 0.48621, 3.54381, 3.32746, 2.23348, 4.2774, 5.61688, 9.05208, 2.97742], fmt = "none")
plt.title("Cv vs. Temperature")
plt.xlabel('KbT/J')
plt.ylabel('Cv')

plt.show()
