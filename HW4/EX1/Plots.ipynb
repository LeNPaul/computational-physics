# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data_1_5_symm.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[1])

for i in range(len(y)):
    x.append(i)

params = {'text.usetex': True}    
    
plt.plot(x[1000:3250],y[1000:3250])
plt.xlabel('E')
plt.ylabel('F(E)')
plt.title('F(E)')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data_1_4_phi.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[2])

for i in range(len(y)):
    x.append(i)

params = {'text.usetex': True}    
    
plt.plot(x[4000:6000],y[4000:6000])
plt.xlabel('$x$')
plt.ylabel('$|\phi_0(x)|^2$')
plt.title('Probability Density for Ground State')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data_1_4_phi.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[2])

for i in range(len(y)):
    x.append(i)

params = {'text.usetex': True}    
    
plt.plot(x[14000:16000],y[14000:16000])
plt.xlabel('$x$')
plt.ylabel('$|\phi_1(x)|^2$')
plt.title('Probability Density for First Excited State')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data_1_4_phi.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[2])

for i in range(len(y)):
    x.append(i)

params = {'text.usetex': True}    
    
plt.plot(x[24000:26000],y[24000:26000])
plt.xlabel('$x$')
plt.ylabel('$|\phi_2(x)|^2$')
plt.title('Probability Density for Second Excited State')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data_1_4_phi.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[2])

for i in range(len(y)):
    x.append(i)

params = {'text.usetex': True}    
    
plt.plot(x[34000:36000],y[34000:36000])
plt.xlabel('$x$')
plt.ylabel('$|\phi_3(x)|^2$')
plt.title('Probability Density for Third Excited State')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data_1_4_phi.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[2])

for i in range(len(y)):
    x.append(i)

params = {'text.usetex': True}    
    
plt.plot(x[44000:46000],y[44000:46000])
plt.xlabel('$x$')
plt.ylabel('$|\phi_4(x)|^2$')
plt.title('Probability Density for Fourth Excited State')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data_1_4_phi.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[2])

for i in range(len(y)):
    x.append(i)

params = {'text.usetex': True}    
    
plt.plot(x[54000:56000],y[54000:56000])
plt.xlabel('$x$')
plt.ylabel('$|\phi_5(x)|^2$')
plt.title('Probability Density for Fifth Excited State')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data_1_4_phi.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[2])

for i in range(len(y)):
    x.append(i)

params = {'text.usetex': True}    
    
plt.plot(x[54000:56000],y[54000:56000])
plt.xlabel('$x$')
plt.ylabel('$|\phi_6(x)|^2$')
plt.title('Probability Density for Sixth Excited State')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data_1_4_phi.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[2])

for i in range(len(y)):
    x.append(i)

params = {'text.usetex': True}    
    
plt.plot(x[64000:66000],y[64000:66000])
plt.xlabel('$x$')
plt.ylabel('$|\phi_7(x)|^2$')
plt.title('Probability Density for Seventh Excited State')
plt.show()
