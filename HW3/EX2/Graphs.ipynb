# %%
import matplotlib.pyplot as plt
import csv

x = [1,2,3]
y = [-4.51545, -4.44888, -4.09221]

params = {'text.usetex': True}    
    
plt.scatter(x[0:10],y[0:10])
plt.xlabel('Energy Level (n)')
plt.ylabel('Energy ($\hbar / 2m$)')
plt.title('Energy levels for L = 10 and M = 50')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = [1,2,3]
y = [-6.26355, -5.95644, -5.74806]

params = {'text.usetex': True}    
    
plt.scatter(x[0:10],y[0:10])
plt.xlabel('Energy Level (n)')
plt.ylabel('Energy ($\hbar / 2m$)')
plt.title('Energy levels for L = 14 and M = 50')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[2])

for i in range(5,len(y),5):
    x.append(i)

params = {'text.usetex': True}    
    
plt.scatter(x[0:10],y[0:10])
plt.xlabel('M')
plt.ylabel('Energy ($\hbar / 2m$)')
plt.title('$E_0$ as a function of M for L = 10')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[3])

for i in range(5,len(y),5):
    x.append(i)

params = {'text.usetex': True}      
    
plt.scatter(x[0:10],y[0:10])
plt.xlabel('M')
plt.ylabel('Energy ($\hbar / 2m$)')
plt.title('$E_1$ as a function of M for L = 10')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[5])

for i in range(5,len(y),5):
    x.append(i)

params = {'text.usetex': True}      
    
plt.scatter(x[0:10],y[0:10])
plt.xlabel('M')
plt.ylabel('Energy ($\hbar / 2m$)')
plt.title('$|E_0 - E^0_{L=10}|$ as a function of M for L = 10')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[2])

for i in range(5,len(y),5):
    x.append(i)

params = {'text.usetex': True}      
    
plt.scatter(x[0:10],y[30:40])
plt.xlabel('M')
plt.ylabel('Energy ($\hbar / 2m$)')
plt.title('$E_0$ as a function of M for L = 14')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[3])

for i in range(5,len(y),5):
    x.append(i)

params = {'text.usetex': True}      
    
plt.scatter(x[0:10],y[30:40])
plt.xlabel('M')
plt.ylabel('Energy ($\hbar / 2m$)')
plt.title('$E_1$ as a function of M for L = 14')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[5])

for i in range(5,len(y),5):
    x.append(i)

params = {'text.usetex': True}  

plt.scatter(x[0:10],y[30:40])
plt.xlabel('M')
plt.ylabel('Energy ($\hbar / 2m$)')
plt.title('$|E_0 - E^0_{L=10}|$ Difference as a function of M for L = 14')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = [10, 12, 14, 16, 18, 20]
y = [0.0665652, 0.355848, 0.307106, 0.27019, 0.241249, 0.217946]

params = {'text.usetex': True}  

plt.scatter(x,y)
plt.xlabel('L')
plt.ylabel('Energy ($\hbar / 2m$)')
plt.yscale('log')
plt.title('$|E_1 - E_0|$ Difference as a function of L')
plt.show()
