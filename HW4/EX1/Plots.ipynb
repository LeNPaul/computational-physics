# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data_potential.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[0])

for i in range(-500,len(y)):
    x.append(i)

params = {'text.usetex': True}    
    
plt.plot(x[0:1000],y[4500:5500])
plt.xlabel('$x$')
plt.ylabel('$V(x)$ $(\hbar^2 / 2m)$')
plt.title('Potential Well for $0.2x^2 - 14$')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data_1_5_symm.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        x.append(row[0])
        y.append(row[1])

params = {'text.usetex': True}    
    
plt.plot(x,y)
plt.xlabel('E')
plt.ylabel('F(E)')
plt.title('F(E)')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data_phi.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[2])

for i in range(len(y)):
    x.append(i)

params = {'text.usetex': True}    
    
plt.plot(x,y)
plt.xlabel('$x$')
plt.ylabel('$|\phi(x)|^2$')
plt.title('Probability Density')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data_phi.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[2])

for i in range(-1000,len(y)):
    x.append(i)

params = {'text.usetex': True}    
    
plt.plot(x[0:2000],y[4000:6000])
plt.xlabel('$x$')
plt.ylabel('$|\phi_0(x)|^2$')
plt.title('Probability Density for Ground State')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data_phi.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[2])

for i in range(-1000,len(y)):
    x.append(i)

params = {'text.usetex': True}    
    
plt.plot(x[0:2000],y[14000:16000])
plt.xlabel('$x$')
plt.ylabel('$|\phi_1(x)|^2$')
plt.title('Probability Density for First Excited State')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data_phi.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[2])

for i in range(-1000,len(y)):
    x.append(i)

params = {'text.usetex': True}    
    
plt.plot(x[0:2000],y[24000:26000])
plt.xlabel('$x$')
plt.ylabel('$|\phi_2(x)|^2$')
plt.title('Probability Density for Second Excited State')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data_phi.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[2])

for i in range(-1000,len(y)):
    x.append(i)

params = {'text.usetex': True}    
    
plt.plot(x[0:2000],y[34000:36000])
plt.xlabel('$x$')
plt.ylabel('$|\phi_3(x)|^2$')
plt.title('Probability Density for Third Excited State')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data_phi.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[2])

for i in range(-1000,len(y)):
    x.append(i)

params = {'text.usetex': True}    
    
plt.plot(x[0:2000],y[44000:46000])
plt.xlabel('$x$')
plt.ylabel('$|\phi_4(x)|^2$')
plt.title('Probability Density for Fourth Excited State')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data_phi.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[2])

for i in range(-1000,len(y)):
    x.append(i)

params = {'text.usetex': True}    
    
plt.plot(x[0:2000],y[54000:56000])
plt.xlabel('$x$')
plt.ylabel('$|\phi_5(x)|^2$')
plt.title('Probability Density for Fifth Excited State')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data_phi.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[2])

for i in range(-1000,len(y)):
    x.append(i)

params = {'text.usetex': True}    
    
plt.plot(x[0:2000],y[64000:66000])
plt.xlabel('$x$')
plt.ylabel('$|\phi_6(x)|^2$')
plt.title('Probability Density for Sixth Excited State')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data_phi.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[3])

for i in range(-1000,len(y)):
    x.append(i)

params = {'text.usetex': True}    
    
plt.plot(x[0:2000],y[4000:6000])
plt.xlabel('$x$')
plt.ylabel('$\phi_0(x)$')
plt.title('Eigenfunction for Ground State')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data_phi.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[3])

for i in range(-1000,len(y)):
    x.append(i)

params = {'text.usetex': True}    
    
plt.plot(x[0:2000],y[14000:16000])
plt.xlabel('$x$')
plt.ylabel('$\phi_1(x)$')
plt.title('Eigenfunction for First Excited State')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data_phi.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[3])

for i in range(-1000,len(y)):
    x.append(i)

params = {'text.usetex': True}    
    
plt.plot(x[0:2000],y[24000:26000])
plt.xlabel('$x$')
plt.ylabel('$\phi_2(x)$')
plt.title('Eigenfunction for Second Excited State')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('data_phi.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    next(csvfile)
    for row in plots:
        y.append(row[3])

for i in range(-1000,len(y)):
    x.append(i)

params = {'text.usetex': True}    
    
plt.plot(x[0:2000],y[34000:36000])
plt.xlabel('$x$')
plt.ylabel('$\phi_3(x)$')
plt.title('Eigenfunction for Third Excited State')
plt.show()
